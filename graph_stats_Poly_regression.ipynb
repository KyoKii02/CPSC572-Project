# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import time
# %matplotlib inline

# %%
# change defaults to be less ugly
mpl.rc('xtick', labelsize=14, color="#222222") 
mpl.rc('ytick', labelsize=14, color="#222222") 
mpl.rc('font', **{'family':'sans-serif','sans-serif':['Arial']})
mpl.rc('font', size=16)
mpl.rc('xtick.major', size=6, width=1)
mpl.rc('xtick.minor', size=3, width=1)
mpl.rc('ytick.major', size=6, width=1)
mpl.rc('ytick.minor', size=3, width=1)
mpl.rc('axes', linewidth=2, edgecolor="#222222", labelcolor="#222222")
mpl.rc('text', usetex=False, color="#222222")

# %%
import networkx as nx
import time

def load_graph(graph_file):
    print(f"Loading graph from {graph_file}...")
    start_time = time.time()
    
    # Load the graph
    G = nx.read_graphml(graph_file)
    
    # Convert position strings back into lists of integers
    for node in G.nodes:
        pos_str = G.nodes[node].get('pos', '')  # Use .get to avoid KeyError if 'pos' does not exist
        if pos_str:  # Check if the position string is not empty
            G.nodes[node]['pos'] = list(map(int, pos_str.split(',')))
        else:
            G.nodes[node]['pos'] = []

    end_time = time.time()
    print(f"Graph loaded in {end_time - start_time:.2f} seconds. It has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    return G

# %%
G = load_graph("spotify_AugWeek1.graphml")
# Out:
# Loading graph from spotify_AugWeek1.graphml...
# Graph loaded in 2.57 seconds. It has 5420 nodes and 114579 edges.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Assuming G is your graph object
# Initialize lists for degrees and durations
degrees = []
durations = []

# Iterate through each node to get its degree and duration
for node in G.nodes:
    degrees.append(G.degree(node))
    durations.append(G.nodes[node]['duration_ms'])

# Convert durations from milliseconds to minutes for a better scale
durations_minutes = [duration / 60000 for duration in durations]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(durations_minutes, degrees, alpha=0.35, edgecolors='none')
plt.title('Track Popularity vs. Track Length')
plt.xlabel('Track Length (minutes)')
plt.ylabel('Popularity (Degree)')
plt.grid(True)
plt.show()

# %%
# Iterate through each node to get its degree and duration
for node in G.nodes:
    degrees.append(G.degree(node))
    durations.append(G.nodes[node]['duration_ms'])

# Convert durations from milliseconds to minutes for a better scale
durations_minutes = [duration / 60000 for duration in durations]

# Filter out the data points where the duration is more than 80 minutes or the degree is above 3000
filtered_degrees = [degree for degree, duration in zip(degrees, durations_minutes) if duration <= 15 and degree <= 1500]
filtered_durations_minutes = [duration for duration in durations_minutes if duration <= 15]
filtered_degrees, filtered_durations_minutes = zip(*[(deg, dur) for deg, dur in zip(filtered_degrees, filtered_durations_minutes) if deg <= 3000])

# Create the scatter plot without outliers
plt.figure(figsize=(10, 6))
plt.scatter(filtered_durations_minutes, filtered_degrees, alpha=0.35, edgecolors='none')
plt.title('Track Popularity vs. Track Length')
plt.xlabel('Track Length (minutes)')
plt.ylabel('Popularity (Degree)')
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import operator

# Ensure the input is a numpy array and reshape it
X = np.array(filtered_durations_minutes).reshape(-1, 1)
y = np.array(filtered_degrees)

# Create polynomial features
degree_of_polynomial = 2  # You can change this value to fit higher degree polynomials
poly_features = PolynomialFeatures(degree=degree_of_polynomial)
X_poly = poly_features.fit_transform(X)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Use the model to predict values
y_poly_pred = model.predict(X_poly)

# Sort the values of X and y_poly_pred for plotting
sorted_zip = sorted(zip(X, y_poly_pred), key=lambda t: t[0])
X_sorted, y_poly_pred_sorted = zip(*sorted_zip)

# Plot the results
plt.scatter(X, y, color='blue', alpha=0.5, label='Data points')
plt.plot(X_sorted, y_poly_pred_sorted, color='red', label='Polynomial Regression Line')
plt.xlabel('Track Length (minutes)')
plt.ylabel('Popularity (Degree)')
plt.title('Polynomial Regression of Track Popularity vs. Track Length')
plt.legend()
plt.show()

# %%
# Print the intercept of the polynomial regression model
intercept = model.intercept_
print(f"Intercept: {intercept}")
# Calculate R^2 value for the polynomial regression model
r_squared = model.score(X_poly, y)
print(f"R-squared: {r_squared}")
# Out:
# Intercept: 38.99620987070842
# R-squared: 0.001907560219713611

# %%
# Initialize lists for degrees and positions
all_degrees = []
all_positions = []

# Iterate through each node to get its degree and all positions
for node in G.nodes:
    node_degree = G.degree(node)
    positions = G.nodes[node]['pos']  # This is now a list of positions
    
    # Append the node's degree for each position it has
    for pos in positions:
        all_degrees.append(node_degree)
        all_positions.append(pos)

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(all_positions, all_degrees, alpha=0.5, edgecolors='none')
plt.title('Track Popularity vs. All Positions on Playlists')
plt.xlabel('Position on Playlist')
plt.ylabel('Popularity (Degree)')
plt.grid(True)
plt.show()

# %%
# Assuming G is your graph object and 'pos' attribute is a list of positions for each node
# Initialize lists for degrees and positions
filtered_degrees = []
filtered_positions = []

# Iterate through each node to get its degree and all positions
for node in G.nodes:
    node_degree = G.degree(node)
    if node_degree <= 1000:  # Check if the degree is less than or equal to 1000
        positions = G.nodes[node]['pos']  # This is now a list of positions
        
        # Append the node's degree for each position it has
        for pos in positions:
            filtered_degrees.append(node_degree)
            filtered_positions.append(pos)

# Create the scatter plot without degrees above 1000
plt.figure(figsize=(10, 6))
plt.scatter(filtered_positions, filtered_degrees, alpha=0.5, edgecolors='none')
plt.title('Track Popularity vs. All Positions on Playlists')
plt.xlabel('Position on Playlist')
plt.ylabel('Popularity (Degree)')
plt.grid(True)
plt.show()

# %%
# Calculate Spearman's rank correlation coefficient
spearman_corr_coef, p_value = stats.spearmanr(filtered_positions, filtered_degrees)

print(f"Spearman's Rank Correlation Coefficient: {spearman_corr_coef}")
print(f"P-value: {p_value}")
# Out:
# Spearman's Rank Correlation Coefficient: -0.05586099272418146
# P-value: 7.74526390669692e-93

# %%
from collections import defaultdict
import matplotlib.pyplot as plt

# Aggregate popularity by artist
artist_popularity = defaultdict(int)
for node in G.nodes:
    artist_popularity[G.nodes[node]['artist_name']] += G.degree(node)

# Sort artists by their aggregated popularity
sorted_artists = sorted(artist_popularity.items(), key=lambda x: x[1], reverse=True)

# Select the top N artists
top_n = 10
top_artists, top_popularities = zip(*sorted_artists[:top_n])

plt.figure(figsize=(12, 8))
plt.bar(top_artists, top_popularities)
plt.title(f'Top {top_n} Artists by Popularity')
plt.xlabel('Artist')
plt.ylabel('Aggregated Popularity')
plt.xticks(rotation=45)
plt.show()

# %%
def degree_distribution_stats(G):
    N = len(G)
    L = G.size()
    degrees = [G.degree(node) for node in G]
    kmin = min(degrees)
    kmax = max(degrees)

    print("Number of nodes: ", N)
    print("Number of edges: ", L)
    print()
    print("Average degree: ", 2*L/N)
    print("Average degree (alternate calculation)", np.mean(degrees))
    print()
    print("Minimum degree: ", kmin)
    print("Maximum degree: ", kmax)

# %%
# Function to plot a degree distribution graph (P(k) vs k graph)

def plot_degree_dist(G, title="Degree Distribution"):
    degrees = [G.degree(n) for n in G.nodes()]
    kmin = min(degrees)
    kmax = max(degrees)
    
    # Specify the number of bins you want
    num_bins = 20  # You can adjust this number based on your preference or dataset size
    
    if kmin > 0:
        bin_edges = np.logspace(np.log10(kmin), np.log10(kmax), num_bins)
    else:
        # Adding .2 to include kmax in the range if kmin is 0
        bin_edges = np.logspace(0, np.log10(kmax) + .2, num_bins)
    
    density, _ = np.histogram(degrees, bins=bin_edges, density=True)

    fig = plt.figure(figsize=(6, 4))

    log_be = np.log10(bin_edges)
    x = 10 ** ((log_be[1:] + log_be[:-1]) / 2)  # Compute geometric mean of bin edges for plotting
    plt.loglog(x, density, marker='o', linestyle='none', color='g')
    plt.xlabel(r"Degree $k$", fontsize=16)
    plt.ylabel(r"$P(k)$", fontsize=16)
    plt.title(title)

    ax = plt.gca()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    plt.show()

# %%
degree_distribution_stats(G)
plot_degree_dist(G, "Chords and Code - Degree Distribution")
# Out:
# Number of nodes:  5420
# Number of edges:  114579
#
# Average degree:  42.28007380073801
# Average degree (alternate calculation) 42.28007380073801
#
# Minimum degree:  1
# Maximum degree:  1528

# %% [markdown]
# # Clustering Coefficient and Shortest Path

# %%
# Find the clustering coefficient for our new filtered graph H
C = np.mean(list(nx.clustering(G).values()))
print("Average Clustering Coefficient: ", C)
# Out:
# Average Clustering Coefficient:  0.6186053620486062

# %% [markdown]
# Now find it for the largest component, to ensure we are calculating it for a component that is entirely connected

# %%
largest_cc = max(nx.connected_components(G), key=len)

# Create a subgraph of G containing only the nodes in largest_cc
G_largest = G.subgraph(largest_cc)

# %%
print(nx.number_connected_components(G))
# Out:
# 36

# %%
# Calculate clustering coefficient
# Calculate the shortest path
C = np.mean(list(nx.clustering(G_largest).values()))
d = nx.average_shortest_path_length(G_largest,weight=None)

print("Average Clustering Coefficient: ", C)
print("Average Shortest Path: ", d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Calculate clustering coefficient
#       2 # Calculate the shortest path
#       3 C = np.mean(list(nx.clustering(G_largest).values()))
# ----> 4 d = nx.average_shortest_path_length(G_largest,weight=None)
#       6 print("Average Clustering Coefficient: ", C)
#       7 print("Average Shortest Path: ", d)
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/utils/backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/generic.py:432, in average_shortest_path_length(G, weight, method)
#     428         return nx.single_source_bellman_ford_path_length(G, v, weight=weight)
#     430 if method in single_source_methods:
#     431     # Sum the distances for each (ordered) pair of source and target node.
# --> 432     s = sum(l for u in G for l in path_length(u).values())
#     433 else:
#     434     if method == "floyd-warshall":
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/generic.py:432, in <genexpr>(.0)
#     428         return nx.single_source_bellman_ford_path_length(G, v, weight=weight)
#     430 if method in single_source_methods:
#     431     # Sum the distances for each (ordered) pair of source and target node.
# --> 432     s = sum(l for u in G for l in path_length(u).values())
#     433 else:
#     434     if method == "floyd-warshall":
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/generic.py:424, in average_shortest_path_length.<locals>.path_length(v)
#     422 def path_length(v):
#     423     if method == "unweighted":
# --> 424         return nx.single_source_shortest_path_length(G, v)
#     425     elif method == "dijkstra":
#     426         return nx.single_source_dijkstra_path_length(G, v, weight=weight)
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/utils/backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/unweighted.py:62, in single_source_shortest_path_length(G, source, cutoff)
#      60     cutoff = float("inf")
#      61 nextlevel = [source]
# ---> 62 return dict(_single_shortest_path_length(G._adj, nextlevel, cutoff))
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/unweighted.py:89, in _single_shortest_path_length(adj, firstlevel, cutoff)
#      87 nextlevel = []
#      88 for v in thislevel:
# ---> 89     for w in adj[v]:
#      90         if w not in seen:
#      91             seen.add(w)
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/classes/coreviews.py:281, in <genexpr>(.0)
#     279 if node_ok_shorter:
#     280     return (n for n in self.NODE_OK.nodes if n in self._atlas)
# --> 281 return (n for n in self._atlas if self.NODE_OK(n))
#
# File ~/Desktop/CPSC 572/myprojectenv/lib/python3.12/site-packages/networkx/classes/coreviews.py:317, in FilterAdjacency.__getitem__.<locals>.new_node_ok(nbr)
#     316 def new_node_ok(nbr):
# --> 317     return self.NODE_OK(nbr) and self.EDGE_OK(node, nbr)
#
# KeyboardInterrupt:

# %% [markdown]
# # Degree Preservation Analysis (ER and Double-Edge Swap)

# %%
GN = len(G.nodes()) # G.number_of_nodes()
max_L = GN*(GN-1)/2
actual_L = len(G.edges())
p = actual_L/max_L

clustering_ER = []
short_path_ER = []

for i in range(100): # 1000 is better
    
    ER = nx.erdos_renyi_graph(GN, p, directed=False)
    C_ER = np.mean(list(nx.clustering(ER).values()))
    if nx.is_connected(ER)==True:
        d_ER = nx.average_shortest_path_length(ER,weight=None)
    clustering_ER.append(C_ER)
    short_path_ER.append(d_ER)
    
print(np.mean(clustering_ER))
print(np.std(clustering_ER))

print(np.mean(short_path_ER))
print(np.std(short_path_ER))
# Out:
# 0.007801313114217683
# 6.771166540408483e-05
# 2.705746813351138
# 0.0014058893056229141

# %%
# Calculating metrics for a Degree Preservation Graph

DP = G.copy()

clustering_DP = []
short_path_DP = []

for i in range(100): # 1000 is better
    
    nx.double_edge_swap(DP,nswap=10*G.number_of_edges(),max_tries=10000000)
    C_DP = np.mean(list(nx.clustering(DP).values()))
    d_DP = None
    if nx.is_connected(DP)==True:
        d_DP = nx.average_shortest_path_length(DP,weight=None)
    clustering_DP.append(C_DP)
    if d_DP is not None:  # Append d_DP only if it's defined
        short_path_DP.append(d_DP)
    
print(np.mean(clustering_DP))
print(np.std(clustering_DP))

print(np.mean(short_path_DP))
print(np.std(short_path_DP))
# Out:
# 0.17562577036279403
# 0.002516002750675417
# 2.76197115757219
# 0.0026808508205250887

# %%
fig = plt.figure(figsize=(6,4))

plt.boxplot([clustering_ER,clustering_DP], positions=[1,2])
plt.plot(3,C,'r',marker='+',markersize=15)
ax = plt.gca()
ax.set_xticks([1,2,3],labels=['ER','DP','Spotify Playlists'])
plt.ylabel('Clustering')
plt.xlim([0.5,3.5])
plt.show()
